# %% [markdown]
# # LIBRARY IMPORT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # 데이터 종류 확인

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.dtypes
# categorical 변수들이 object로 되어있는것을 확인한다.
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# # 결측치 확인

# %%
df.isnull().sum().sum()
#없는것을 확인
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # outlier check

# %%
q = df.quantile(0.99)
q
# Out:
# Age                            58.31
# DailyRate                    1485.00
# DistanceFromHome               29.00
# Education                       5.00
# EmployeeCount                   1.00
# EmployeeNumber               2046.62
# EnvironmentSatisfaction         4.00
# HourlyRate                    100.00
# JobInvolvement                  4.00
# JobLevel                        5.00
# JobSatisfaction                 4.00
# MonthlyIncome               19626.31
# MonthlyRate                 26704.24
# NumCompaniesWorked              9.00
# PercentSalaryHike              25.00
# PerformanceRating               4.00
# RelationshipSatisfaction        4.00
# StandardHours                  80.00
# StockOptionLevel                3.00
# TotalWorkingYears              35.00
# TrainingTimesLastYear           6.00
# WorkLifeBalance                 4.00
# YearsAtCompany                 31.00
# YearsInCurrentRole             15.00
# YearsSinceLastPromotion        14.00
# ...

# %%
q_low = df.quantile(0.01)
q_hi  = df.quantile(0.99)

df_filtered = df[(df < q_hi) & (df > q_low)]
# Out:
# <ipython-input-96-9e37811df87f>:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df_filtered = df[(df < q_hi) & (df > q_low)]

# %%
df_filtered
# Out:
#        Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0     41.0       NaN            NaN     1102.0        NaN               NaN
# 1     49.0       NaN            NaN      279.0        NaN               8.0
# 2     37.0       NaN            NaN     1373.0        NaN               2.0
# 3     33.0       NaN            NaN     1392.0        NaN               3.0
# 4     27.0       NaN            NaN      591.0        NaN               2.0
# ...    ...       ...            ...        ...        ...               ...
# 1465  36.0       NaN            NaN      884.0        NaN              23.0
# 1466  39.0       NaN            NaN      613.0        NaN               6.0
# 1467  27.0       NaN            NaN      155.0        NaN               4.0
# 1468  49.0       NaN            NaN     1023.0        NaN               2.0
# 1469  34.0       NaN            NaN      628.0        NaN               8.0
#
# ...

# %% [markdown]
# # Data Visualization

# %%
yes = df[df['Attrition'] == 'Yes'].describe().T
no = df[df['Attrition'] == 'No'].describe().T

# %%
#각각 변수별로 attrition을 확인

# %%
fig,ax = plt.subplots(nrows = 1,ncols = 2,figsize = (10,10))
plt.subplot(1,2,1)
sns.heatmap(yes[['mean']],annot = True,linewidths = 0.4,linecolor = 'black',cbar = False,fmt = '.2f')
plt.title('Mean Values : Attrited Employees');

plt.subplot(1,2,2)
sns.heatmap(no[['mean']],annot = True,linewidths = 0.4,linecolor = 'black',cbar = False,fmt = '.2f')
plt.title('Mean Values : Retained Employees');

fig.tight_layout(pad = 2)

# %%
#exploring the categories of Attrition column
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize= (8, 6))
data_pie  = [237 , 1233]
labels = ["Yes", "No"]
explode = [0.1, 0]
plt.pie(data_pie ,labels= labels , explode = explode , autopct="%1.2f%%", shadow= True, colors= ['#722F37', '#915F6D'])
plt.legend()
plt.show()

# %%
# gender 확인

# %%
sns.barplot( y = 'PerformanceRating', x = 'Gender', data = df, palette ="viridis")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='PerformanceRating'>

# %%
sns.countplot(x="BusinessTravel", hue="Attrition", data = df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x="Department", hue = "Attrition", data = df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %%
sns.displot(data = df, x = "JobInvolvement", hue = "Attrition")

# %%
sns.displot(data = df, x = "JobRole", hue = "Attrition", height = 20)

# %% [markdown]
# # Numeric or Categorical 변수 확인

# %%
#numeric feature들
num_features = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
                 'PercentSalaryHike', 'StandardHours', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 
                 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

#categorical feature들
cate_features = ['Attrition', 'BusinessTravel','Department', 'Education', 'EducationField', 'EmployeeCount','EmployeeNumber',
                    'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
                    'MaritalStatus', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
                    'WorkLifeBalance']

# %%
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

# %%
# categorical feature들을 labeling 숫자로 바꿔준다

# %%
le = LabelEncoder()
l1 = []; l2 = []; text_categorical_features = []
print('Label Encoder Transformation')
for i in tqdm(cate_features):
    if type(df[i][0]) ==  str:
        text_categorical_features.append(i)
        df[i] = le.fit_transform(df[i])
        l1.append(list(df[i].unique())); l2.append(list(le.inverse_transform(df[i].unique())))
        print(i,' : ',df[i].unique(),' = ',le.inverse_transform(df[i].unique()))
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 970.22it/s]
# Label Encoder Transformation
# Attrition  :  [1 0]  =  ['Yes' 'No']
# BusinessTravel  :  [2 1 0]  =  ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department  :  [2 1 0]  =  ['Sales' 'Research & Development' 'Human Resources']
# EducationField  :  [1 4 3 2 5 0]  =  ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender  :  [0 1]  =  ['Female' 'Male']
# JobRole  :  [7 6 2 4 0 3 8 5 1]  =  ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus  :  [2 1 0]  =  ['Single' 'Married' 'Divorced']
# Over18  :  [0]  =  ['Y']
# OverTime  :  [1 0]  =  ['Yes' 'No']

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# # categorical 변수 시각화

# %%
for i in range(5):
    fig, ax = plt.subplots(nrows = 1,ncols = 4,figsize = (15,3))
    a = 1
    for j in categorical_features[(i*4) : (i*4) + 4]:
        plt.subplot(1,4,a) 
        sns.distplot(df[j],kde_kws = {'bw' : 1});
        plt.title('Distribution : ' + j)
        a += 1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %% [markdown]
# # 상관성 분석

# %%
r = np.corrcoef(df['DistanceFromHome'], df['DailyRate'])
r
# Out:
# array([[ 1.        , -0.00498534],
#        [-0.00498534,  1.        ]])

# %%
#전체 데이터로 확인 
df.corr().mean()
# Out:
# Age                         0.178335
# DailyRate                   0.043397
# DistanceFromHome            0.048611
# Education                   0.080468
# EmployeeCount                    NaN
# EmployeeNumber              0.038846
# EnvironmentSatisfaction     0.040385
# HourlyRate                  0.039582
# JobInvolvement              0.044475
# JobLevel                    0.213623
# JobSatisfaction             0.030161
# MonthlyIncome               0.208113
# MonthlyRate                 0.042417
# NumCompaniesWorked          0.066775
# PercentSalaryHike           0.065238
# PerformanceRating           0.070101
# RelationshipSatisfaction    0.045050
# StandardHours                    NaN
# StockOptionLevel            0.058407
# TotalWorkingYears           0.231670
# TrainingTimesLastYear       0.031996
# WorkLifeBalance             0.046543
# YearsAtCompany              0.208347
# YearsInCurrentRole          0.189097
# YearsSinceLastPromotion     0.165886
# ...

# %%
corr = df.corr("pearson")
plt.figure(figsize = (10,10))
sns.heatmap(corr, linewidth = 1)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,10))
sns.heatmap(abs(corr) > 0.75, linewidth = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# JobLevel, MonthlyIncome, TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsWithCurrentManager 변수들이 상관성이 높아 모델에 같이 넣었을 경우 충돌을 유발할 경우가 있음
